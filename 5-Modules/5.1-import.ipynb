# %% [markdown]
# ## Import Modules in Python: Modules and Packages

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
print(f"{pi:.2f}")
# Out:
# 4.0
# 5.0
# 3.141592653589793
# 3.14

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import sys
print(sys.executable)
# Out:
# d:\code\venv\python.exe

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.2-cp312-cp312-win_amd64.whl (12.3 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seaborn 0.13.2 requires matplotlib!=3.6.1,>=3.4, which is not installed.
# pandas 2.2.0 requires numpy<2,>=1.26.0; python_version >= "3.12", but you have numpy 2.4.2 which is incompatible.

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(2,3)
# Out:
# 5

# %%
from package.maths import *

print(addition(2,3))
print(subtraction(2,3))
# Out:
# 5
# -1
