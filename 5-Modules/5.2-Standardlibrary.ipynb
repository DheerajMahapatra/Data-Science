# %% [markdown]
# ## Standard Library Overview

# %%
import array
arr = array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## Random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 9
# cherry

# %%
### File And Directory Access

import os
print(os.getcwd())
# Out:
# d:\code\5-Modules

# %%
os.mkdir('test_dir')

# %%
## Normal File Create

with open("test.txt", "w") as f:
    f.write("Hello Dheeraj")

# %%
## File inside Directory

with open("test_dir/sample.txt", "w") as f:
    f.write("Inside folder")

# %%
## Using OS Module

import os

file_path = os.path.join("test_dir", "data.txt")

with open(file_path, "w") as f:
    f.write("Data science loading...")

# %%
## High level operation  on file and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization

import json
data = {'name':'Dheeraj', 'age':21}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Dheeraj", "age": 21}
# <class 'str'>
# {'name': 'Dheeraj', 'age': 21}
# <class 'dict'>

# %%
## csv
import csv

with open('example.csv', mode = 'w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Dheeraj', 21])
    
with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Dheeraj', '21']

# %%
## datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now-timedelta(days = 1)
print(yesterday)

# 2 ghante
print(now - timedelta(hours=2))

# 30 minute
print(now + timedelta(minutes=30))
# Out:
# 2026-03-02 23:57:50.892940
# 2026-03-01 23:57:50.892940
# 2026-03-02 21:57:50.892940
# 2026-03-03 00:27:50.892940

# %%
## time

import time
print(time.time())
time.sleep(2)
print(time.time())

'''Number of seconds since 1 January 1970 (Unix Epoch)'''
# start = time.time()

# time.sleep(2)

# end = time.time()

# print("Time taken:", end - start)
# Out:
# 1772476371.1822984
# 1772476373.1836915
# 'Number of seconds since 1 January 1970 (Unix Epoch)'

# %%
## Regular expression

import re

pattern = r'\d+'
text = 'There are 123 apples 456'
match = re.search(pattern,text)
print(match.group())


matches = re.findall(pattern, text)
print(matches)
# Out:
# 123
# ['123', '456']

# %%
import re

text = "Contact: test@gmail.com"
pattern = r'(\w+)@(\w+)\.(\w+)'

match = re.search(pattern, text)

print("Full:", match.group())
print("Username:", match.group(1))
print("Domain:", match.group(2))
# Out:
# Full: test@gmail.com
# Username: test
# Domain: gmail
